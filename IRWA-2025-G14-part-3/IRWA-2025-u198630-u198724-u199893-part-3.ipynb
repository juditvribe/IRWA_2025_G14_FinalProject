# %% [markdown]
# # **Information Retrieval and Web Analysis (IRWA)**
# ##**Final Project - G014**
# Paula Ceprián (u198630)
#
# Judit Viladecans (u198724)
#
# Berta Noguera (u199893)

# %% [markdown]
# This notebook is part of the **Information Retrieval and Web Analytics (IRWA) project**, which aims to build a **Retrieval-Augmented Generation (RAG) system** supported by a custom search engine. The notebook covers Parts 1, 2, and 3 of the project:
# - **Part 1** involves text processing and exploratory data analysis (EDA) to understand and prepare the dataset through cleaning and word exploration.
# - **Part 2** focuses on indexing and evaluation, implementing efficient data structures and metrics to assess retrieval performance.
# - **Part 3** addresses ranking and filtering, applying algorithms to improve the relevance and quality of retrieved results.

# %% [markdown]
# ## **Import Basic Libraries and Datasets**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# if you do not have 'nltk', the following command should work "python -m pip install nltk"
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# !pip install gensim
from gensim.models import Word2Vec
# Out:
# Collecting gensim
#   Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.5.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.0.1)
# Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (27.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 59.8 MB/s eta 0:00:00
# Installing collected packages: gensim
# Successfully installed gensim-4.4.0

# %%
from collections import defaultdict, Counter
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import PCA
from array import array
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from numpy import linalg as la
from wordcloud import WordCloud

import re
import math
import spacy
import numpy as np
import collections
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Berta's fashion path: /content/drive/MyDrive/5è curs/Labs IRWA/IRWA Labs/PART 1 Final Project/fashion_products_dataset.json
# Berta's validation path: /content/drive/MyDrive/5è curs/Labs IRWA/IRWA Labs/PART 1 Final Project/validation_labels.csv
# Paula's fashion path:/content/drive/MyDrive/Quinto/IRWA/IRWA Labs/PART 1 Final Project/fashion_products_dataset.json
# Paula's validation path: /content/drive/MyDrive/Quinto/IRWA/IRWA Labs/PART 1 Final Project/validation_labels.csv
# Judit's fashion path: /content/drive/MyDrive/5è CURS/IRWA/IRWA Labs/PART 1 Final Project/fashion_products_dataset.json
# Judit's validation path: /content/drive/MyDrive/5è CURS/IRWA/IRWA Labs/PART 1 Final Project/validation_labels.csv

fashion_path = "/content/drive/MyDrive/5è CURS/IRWA/IRWA Labs/PART 1 Final Project/fashion_products_dataset.json"
fashion_df = pd.read_json(fashion_path)

validation_path = "/content/drive/MyDrive/5è CURS/IRWA/IRWA Labs/PART 1 Final Project/validation_labels.csv"
val_df = pd.read_csv(validation_path)

# %% [markdown]
# ## **Part 1: Text Processing and Exploratory Data Analysis**

# %% [markdown]
# ### **1. Data preparation**
#
# We must pre-process the documents. In particular, for the text fields we should:
# - Remove stop words and punctuation marks
# - Do tokenization and stemming
#
# We must take into account that for future queries, the final output will return the following information for each of the selected documents: `pid`, `title`, `description`, `brand`, `category`, `sub_category`, `product_details`, `seller`, `out_of_stock`, `selling_price`, `discount`, `actual_price`, `average_rating`, `url`.

# %%
# Function to process each product registered by eliminating stop words and punctuation marks, as well as doing stemming and tokenization
def build_terms(line):
    """
    Preprocess the specific text related to an article by removing stop words, stemming,
    transforming in lowercase, removing punctuation and return the tokens of the text.

    Argument:
    line -- string (text) to be preprocessed

    Returns:
    line - a list of tokens corresponding to the input text after the preprocessing
    """

    stemmer = PorterStemmer()
    stop_words = set(stopwords.words("english"))

    line=  line.lower()  # Transform in lowercase
    line= re.sub(r'[^\w\s]', '', line)  # Remove punctuation
    line= re.sub(r'[0-9]', '', line)  # Remove numbers
    line =  line.split()
    line= [word for word in line if word not in stop_words]  # Eliminate the stopwords
    line= [stemmer.stem(word) for word in line]  # Perform stemming

    return line

# %%
# Function to process the "product details" of the articles
def flatten_product_details(details):
    """
    Preprocess the text in "product details" and store it as a unique text.

    Argument:
    details -- dictionary to be preprocessed

    Returns:
    str(details) - unique string corresponding to the input details after the preprocessing
    """
    if isinstance(details, list):
        return " ".join(f"{k} {v}" for d in details for k, v in d.items())
    return str(details)

# %%
# First, process "product details" in order to have them as a unique string
fashion_df["product_details"] = fashion_df["product_details"].apply(flatten_product_details)

# Select the text fields that should be processed
fashion_df_text = fashion_df[["pid", "title", "description", "category", "sub_category", "brand", "seller", "product_details"]]
fashion_df_text.set_index("pid", inplace=True)

# Preprocess the text in each field by applying the function "build_terms"
for col in fashion_df_text.columns:
  fashion_df_text[col] = fashion_df_text[col].apply(build_terms)
# Out:
# /tmp/ipython-input-1485922386.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fashion_df_text[col] = fashion_df_text[col].apply(build_terms)

# %%
# Select the numerical columns of the initial dataset
fashion_df_other = fashion_df[["pid", "out_of_stock", "selling_price", "discount", "actual_price", "average_rating", "url"]]

# Merge the new processed textual columns with the numerical columns
fashion_df_processed = fashion_df_text.merge(fashion_df_other, how='left', left_index=True, right_on="pid")

# Order the columns in the specified order
fashion_df_processed = fashion_df_processed[["pid", "title", "description", "brand", "category", "sub_category",
                                             "product_details", "seller", "out_of_stock", "selling_price",
                                             "discount", "actual_price", "average_rating", "url"]]

# %% [markdown]
# ### **2. Exploratory Data Analysis**
#
# When working with data, it is important to have a better understanding of the content and
# some statistics.
#
# In this section, we provide an exploratory data analysis to describe the dataset we are working on in this project and explain the decisions made for the analysis. Some visualizations and analysis that we have created are the following: word counting distribution, average sentence length, vocabulary size, ranking of products, among others.

# %%
# Helper function to plot the top 10 values in a distribution or a ranking
def plot_top_10(dic, category, xlabel, ylabel, color):

    # Order the dictionary by values in descending order and get the top 10
    top_10 = dict(sorted(dic.items(), key=lambda item: item[1], reverse=True)[:10])

    # Obtain the keys and the values
    keys = list(top_10.keys())
    values = list(top_10.values())

    # Create a bar plot
    plt.figure(figsize=(12, 6))
    plt.bar(keys, values, color=color)
    plt.plot(keys, values, color='red', marker='o')
    plt.title(f'Top 10 {category}')
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.xticks(rotation=50)  # Rotate x labels for better visibility
    plt.grid(axis='y')
    plt.tight_layout()  # Avoid overlap
    plt.show()

# %% [markdown]
# #### 2.1. Word Counting Distribution

# %%
# Function to compute number of occurrences of each word
def word_count(df, fields):
  words = {}
  for doc_id, row in df.iterrows(): # For each product registered
    for field in fields:
      for word in row[field]:
        if word in words:
          words[word] += 1
        else:
          words[word] = 1

  # Order the dictionary of occurrences in descending order
  word_count = dict(sorted(words.items(), key = lambda item:item[1], reverse = True))
  return word_count

# %%
word_ocurrences = word_count(fashion_df_processed, ["title", "description"])
plot_top_10(word_ocurrences, "Words in the Title and Description of the Products", "Words", "Counting", "palevioletred")

# %% [markdown]
# #### 2.2. Average Sequence Length and Vocabulary Size

# %%
# Function to compute the average length of the text in a particular field
def avg_length(df, field):
  sum = 0
  for doc_id, product in df.iterrows(): # For each product registered
    sum += len(product[field]) # Sum the number of tokens
  return sum / df.shape[0]

# %%
avg_title_length = avg_length(fashion_df_processed, "title")
avg_description_length = avg_length(fashion_df_processed, "description")
print(f'Average length of the title: {avg_title_length:.2f} words')
print(f'Average length of the description: {avg_description_length:.2f} words')
# Out:
# Average length of the title: 6.05 words
# Average length of the description: 18.18 words

# %%
print(f'Vocabulary size of the title and description of the products: {len(word_ocurrences)}')
print(f'Average number of unique words per product (considering only title and description): \
{len(word_ocurrences)/fashion_df_processed.shape[0]:.2f}')
# Out:
# Vocabulary size of the title and description of the products: 5778
# Average number of unique words per product (considering only title and description): 0.21

# %% [markdown]
# #### 2.3. Ranking of Products (Subcategories)

# %%
fashion_df_2 = fashion_df.copy()

# Process "average rating" to do the ranking of best rated products
fashion_df_2 = fashion_df_2[~(fashion_df_2["average_rating"] == "")]
fashion_df_2["average_rating"] = fashion_df_2["average_rating"].dropna().astype(float)

# Process "actual price" and "selling price" to do the ranking of most expensive products
fashion_df_2 = fashion_df_2[~(fashion_df_2["actual_price"] == "")]
fashion_df_2["actual_price"] = fashion_df_2["actual_price"].str.replace(",", ".").astype(float)
fashion_df_2 = fashion_df_2[~(fashion_df_2["selling_price"] == "")]
fashion_df_2["selling_price"] = fashion_df_2["selling_price"].str.replace(",", ".").astype(float)

# Process "discount" to do the ranking of products with more discount
fashion_df_2 = fashion_df_2[~(fashion_df_2["discount"] == "")]
fashion_df_2["discount"] = fashion_df_2["discount"].str.replace("%", "") .str.replace("off", "").str.strip().astype(float)

# Show the plots
for column in ["average_rating", "actual_price", "selling_price", "discount"]:
  column_name = column.replace('_', ' ').title()
  top_ranking = fashion_df_2.groupby("sub_category")[column].mean().sort_values(ascending=False).to_dict()
  plot_top_10(top_ranking, f"Subcategories according to {column_name}", "Subcategory", column_name, "plum")

# %% [markdown]
# #### 2.4. Top Brands and Sellers

# %%
fashion_df_2 = fashion_df.copy()

# Process "average rating" to do the ranking of best rated brands and sellers
fashion_df_2 = fashion_df_2[~(fashion_df_2["average_rating"] == "")]
fashion_df_2["average_rating"] = fashion_df_2["average_rating"].dropna().astype(float)

# Show the plots
for column in ["brand", "seller"]:
  column_name = column.replace('_', ' ').title()
  top_ranking = fashion_df_2.groupby(column)["average_rating"].mean().sort_values(ascending=False).to_dict()
  plot_top_10(top_ranking, f"{column_name}s", column_name, "Average Rating", "pink")

# %% [markdown]
# #### 2.5. Out-of-stock Distribution

# %%
# Count of in-stock vs out-of-stock
stock_counts = fashion_df["out_of_stock"].value_counts()

plt.figure(figsize=(6, 6))
plt.pie(stock_counts,  # Number of times of each value (True and False)
        labels=["In Stock", "Out of Stock"], # True = In Stock, False = Out of Stock
        autopct="%1.2f%%", # Format of the percentage (only 2 decimals)
        pctdistance=0.85, startangle=90, # Position of the numbers in the pie and the different wedges
        colors=["violet", "darkviolet"])

plt.title("Out-of-Stock Distribution")
plt.show()

# %% [markdown]
# #### 2.6. Word Cloud for Word Counting Distribution

# %%
# Generate word cloud based on the word counting distribution previously computed
fashion_wordcloud = WordCloud(width=1000, height=400, background_color='white', colormap= 'RdPu')
fashion_wordcloud.generate_from_frequencies(dict(word_ocurrences))

# Show the word cloud
f, ax = plt.subplots(figsize=(16, 8))
plt.imshow(fashion_wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# #### 2.7. Entity Recognition

# %%
# Load the English NLP (Natural Language Processing) model
nlp = spacy.load("en_core_web_sm")

# Consider only the titles of the products
title_data = fashion_df["title"].dropna().unique()
titles = " ".join(title_data)

# Process all titles as one unique text
doc = nlp(titles)
entities = [(ent.text, ent.label_) for ent in doc.ents]

# Store results as a dataframe for better visualization
entities_df = pd.DataFrame(entities, columns=["entity", "label"])
entities_df.head(10)
# Out:
#                                               entity     label
# 0                                        Solid Women    PERSON
# 1                         -Lite Satin Tie & Cufflink       ORG
# 2                                              Beige    PERSON
# 3                                              Brown    PERSON
# 4                                              Brown    PERSON
# 5                                      Brown Sweater    PERSON
# 6  Black Sweater Solid Men Raincoat Self Design M...       ORG
# 7                                                  2  CARDINAL
# 8                            Solid Men Polo Neck Red    PERSON
# 9                           Grey T-Shirt  (Pack of 2       ORG

# %% [markdown]
# ## **Part 2: Indexing and Evaluation**

# %% [markdown]
# ### **1. Indexing**

# %% [markdown]
# #### 1.1. Index Function

# %%
def create_index_fashion_fields(fashion_df):
    """
    Implement the inverted index
    Argument:
      fashion_df -- collection of registered articles
    Returns:
      index - the inverted index (implemented through a Python dictionary)
      containing terms as keys and the corresponding list of documents where
      these keys appears in (and the field) as values.
    """
    index = defaultdict(list)
    title_index = {}

    for doc_id, row in fashion_df.iterrows():
        doc_id = row['pid']
        title_index[doc_id] = row['title']

        # Temporary index for the current article/product
        current_page_index = {}

        # Go through each field of the dataset
        for field in ['title', 'description', 'category', 'sub_category', 'brand',
                      'product_details', 'seller']:
            terms = build_terms(row[field])
            for term in terms:
                try:
                    # If we already have the term in the dictionary, append the current field
                    if field not in current_page_index[term][1]:
                        current_page_index[term][1].append(field)
                except KeyError:
                    # If it is the first time that the term appears, add in the dictionary
                    #with the current field
                    current_page_index[term] = [doc_id, [field]]

        # Aggregate the current index to the global index
        for term, posting in current_page_index.items():
            index[term].append(posting)

    return index, title_index

# %%
index, title_index = create_index_fashion_fields(fashion_df)

print(index['cotton'])
# Out:
# [['TKPFCZ9EA7H5FYZH', ['description', 'product_details']], ['TKPFCZ9EJZV2UVRZ', ['description', 'product_details']], ['TKPFCZ9EHFCY5Z4Y', ['description', 'product_details']], ['TKPFCZ9ESZZ7YWEF', ['description', 'product_details']], ['TKPFCZ9EVXKBSUD7', ['description', 'product_details']], ['TKPFCZ9EFK9DNWDA', ['description', 'product_details']], ['TKPFDABN3GXYPFHE', ['description', 'product_details']], ['TKPFCZ9ESGZYT8NH', ['description', 'product_details']], ['TKPFCZ9DYU33FFXS', ['description', 'product_details']], ['TKPFDABN4NQFVKZY', ['description', 'product_details']], ['TKPFCZ9ENWGMX23W', ['description', 'product_details']], ['TKPFZFSHHACG3FHC', ['product_details']], ['TKPFZFSHQPDRGZTM', ['product_details']], ['TKPFZ4YTRF3ZRTTH', ['product_details']], ['TKPFZ4YTJZWBFYFZ', ['product_details']], ['TKPFZFSH3F9ZA7C6', ['product_details']], ['TKPFZ4YT7ZNYXG27', ['product_details']], ['TKPFZ4YTGNZJDZDU', ['product_details']], ['TKPFZ4YTX94CY9JX', ['product_details']], ['TKPFCZ9EHCNAPKPU', ['description', 'product_details']], ['TKPFDACEXAWUHGR7', ['description', 'product_details']], ['TKPFCZ9ETR6YVXNG', ['description', 'product_details']], ['TKPFD3K6K5TNYZGF', ['description', 'product_details']], ['TKPFCZ9EGGYENTZS', ['description', 'product_details']], ['TKPFD3K6ZMN79MPH', ['description', 'product_details']], ['TKPFD3K6UZBYDZNY', ['description', 'product_details']], ['TKPFD3K62JB9PEMR', ['description', 'product_details']], ['TKPFCZ9EZDPZR5AH', ['description', 'product_details']], ['TKPFWBGVGU9FCAYX', ['product_details']], ['TKPFWBGPGVKVZARU', ['product_details']], ['TKPFCZ9EVM2GZ4GF', ['description', 'product_details']], ['TKPFWAG7YFWPMG5Y', ['product_details']], ['TKPFCZ9E2UC3DR3F', ['description', 'product_details']], ['TKPFCZ9ECDYYDNKA', ['description', 'product_details']], ['SOCFVCCYUDEN2AVH', ['description', 'product_details']], ['TSHFWSZJQSCYKUJJ', ['product_details']], ['TSHFWSZJUQSDZZHG', ['product_details']], ['TSHFWSZJZNHNPX2Y', ['product_details']], ['TSHFWTPXBG5SZDV7', ['product_details']], ['SHTFVVEHGJJTM4QN', ['description', 'product_details']], ['TSHFYC82QKRSV6ZA', ['description', 'product_details']], ['SHTFVVEHJKNZ7VNR', ['description', 'product_details']], ['TSHFYC82QNATNDPD', ['description', 'product_details']], ['SHTFVVEHWHRGQMKY', ['description', 'product_details']], ['TSHFYF6KNCXDJRFG', ['product_details']], ['TSHFWSZJDWBTC7PP', ['product_details']], ['TSHFWYV9YZABZYBV', ['product_details']], ['TSHFWSZJFCQGDD9R', ['product_details']], ['SHTFVVEHFY5F4QVH', ['description', 'product_details']], ['TSHFYEHZRN8A7ZEP', ['product_details']], ['TSHFYF6GEZGKCHZA', ['product_details']], ['TSHFYEEPZDU5ZYUA', ['product_details']], ['TSHFWYV9GCKA3WWP', ['product_details']], ['TSHFWTMGVUBKW4M8', ['product_details']], ['TSHFWYV9GJ8FWQGG', ['product_details']], ['TSHFYEESCZZGQVDJ', ['product_details']], ['TSHFWTMGFADKY7S8', ['product_details']], ['TSHFWTRVHMN9MG7V', ['product_details']], ['TSHFWTPXPAMQ9YCE', ['product_details']], ['TSHFWTRVUFHQYK6F', ['product_details']], ['TSHFWTRVHHXNDYVZ', ['product_details']], ['SHTFVVEHGB3M4JVU', ['description', 'product_details']], ['SHTFVVCNTBZUFGXR', ['description', 'product_details']], ['TSHFWTRVHPKXGTVJ', ['product_details']], ['TSHFYF6BFWFHZCG4', ['product_details']], ['TSHFYFASUQVT8ZVE', ['product_details']], ['SHTFVVCNDWPWPQDE', ['description', 'product_details']], ['SHTFVVCNJNSZGNZ3', ['description', 'product_details']], ['TSHFYFAS8VN6H3EC', ['product_details']], ['TSHFYFAS85VY8HRA', ['product_details']], ['TSHFYFASBA2GKAEA', ['product_details']], ['TSHFYFASJGCMTFZJ', ['product_details']], ['TSHFYFATXGZDX5WB', ['product_details']], ['TSHFYFASFTHCYMHG', ['product_details']], ['TSHFYFASG5GVRRGB', ['product_details']], ['TSHFYFKS6JUSUTUS', ['product_details']], ['TSHFYFASMT4X5T4V', ['product_details']], ['TSHFYFASDZGH7FPG', ['product_details']], ['TSHFYFASCWHRDGGH', ['product_details']], ['TSHFYFASNXPF75MU', ['product_details']], ['TSHFYFATFYAY698Z', ['product_details']], ['TSHF ...

# %% [markdown]
# #### 1.2. Test Queries

# %%
def search(query, index):
    """
    The output is the list of documents that contain any of the query terms.
    So, we will get the list of documents for each query term, and take the union of them.
    """
    query = build_terms(query) # so that stemed terms are matched in the index
    term_docs = [posting[0] for posting in index[query[0]]]
    docs = set(term_docs)
    for term in query[1:]:
        try:
            # Store in term_docs the ids of the docs that contain "term"
            term_docs = [posting[0] for posting in index[term]]
            # docs = docs ∩ term_docs (intersection) --> to find the products with all the words in the query
            docs &= set(term_docs)
        except:
            # Term is not in index
            pass
    docs = list(docs)
    return docs

# %%
# QUERY 1
query_1 = "Comfort Women Dark Blue T-Shirt"
print(query_1)
docs = search(query_1, index)
top = 10

print("\n======================\nSample of {} results out of {} for the searched query:\n".format(min(top,len(docs)), len(docs)))
for d_id in docs[:top]:
    print("Register ID= {} - Product Title: {}".format(d_id, title_index[d_id]))
# Out:
# Comfort Women Dark Blue T-Shirt
#
# ======================
# Sample of 10 results out of 111 for the searched query:
#
# Register ID= TSHF34PEGC9AENZH - Product Title: Solid Women Round Neck Light Blue T-Shirt
# Register ID= TSHFDT666SFHTEWZ - Product Title: Solid Women Round Neck Blue T-Shirt
# Register ID= TSHF6RWFHSCZFJFC - Product Title: Printed Women Polo Neck Dark Blue T-Shirt
# Register ID= TSHFGZXPCHGDKYF4 - Product Title: Sporty Women Round Neck Dark Blue T-Shirt
# Register ID= TSHFGDDXPJHJCRPH - Product Title: Self Design, Solid Women Polo Neck Dark Blue, Light Blue, Green T-Shirt  (Pack of 3)
# Register ID= TSHFHBNTGUXGGDMY - Product Title: Solid Women Polo Neck Dark Blue, Blue, Pink T-Shirt  (Pack of 3)
# Register ID= TSHFJVWFNSR28NZM - Product Title: Solid Women Round Neck Dark Blue T-Shirt
# Register ID= SWSFWEFYYTUBWZXA - Product Title: Full Sleeve Graphic Print Women Sweatshirt
# Register ID= TSHFMHQBHEAJNJD6 - Product Title: Printed Women Round Neck Dark Blue T-Shirt
# Register ID= TSHFGBY83GKPWJYY - Product Title: Self Design, Solid Women Polo Neck Dark Blue, Blue, Orange T-Shirt  (Pack of 3)

# %%
# QUERY 2
query_2 = "Green Stripe Men Cotton Polo"
print(query_2)
docs = search(query_2, index)
top = 10

print("\n======================\nSample of {} results out of {} for the searched query:\n".format(min(top,len(docs)), len(docs)))
for d_id in docs[:top]:
    print("Register ID= {} - Product Title: {}".format(d_id, title_index[d_id]))
# Out:
# Green Stripe Men Cotton Polo
#
# ======================
# Sample of 10 results out of 29 for the searched query:
#
# Register ID= TSHFY6ZWH4GTFFC8 - Product Title: Striped Men Polo Neck Green T-Shirt
# Register ID= TSHEUJ44HVSVX6JF - Product Title: Striped Men Polo Neck Green T-Shirt
# Register ID= TSHFKKCXY9YYQP4U - Product Title: Striped Men Polo Neck Grey T-Shirt
# Register ID= TSHFYNFZFBASDYEH - Product Title: Striped Men Polo Neck Green, Yellow T-Shirt
# Register ID= TSHFVSZ29JFQ7NH8 - Product Title: Striped Men Polo Neck Light Green, Dark Blue T-Shirt
# Register ID= TSHFVQJRQQMSTHYS - Product Title: Striped Men Polo Neck Light Green T-Shirt
# Register ID= TSHFVQJQFDTTBYSH - Product Title: Striped Men Polo Neck Green T-Shirt
# Register ID= TSHFVHCMCCMFWC4G - Product Title: Striped Men Polo Neck Green T-Shirt
# Register ID= TSHFG2HT6EMKGP7W - Product Title: Striped Men Polo Neck Multicolor T-Shirt  (Pack of 2)
# Register ID= TSHFG2HTXEHZNGGZ - Product Title: Striped Men Polo Neck Multicolor T-Shirt  (Pack of 2)

# %%
# QUERY 3
query_3 = "Solid Track Black Pants for Men"
print(query_3)
docs = search(query_3, index)
top = 10

print("\n======================\nSample of {} results out of {} for the searched query:\n".format(min(top,len(docs)), len(docs)))
for d_id in docs[:top]:
    print("Register ID= {} - Product Title: {}".format(d_id, title_index[d_id]))
# Out:
# Solid Track Black Pants for Men
#
# ======================
# Sample of 10 results out of 182 for the searched query:
#
# Register ID= TKPFZ3Z8BFRVN35S - Product Title: Solid Men Black Track Pants
# Register ID= TKPFZHZ4QQNSNYNK - Product Title: Solid Men Maroon, Black Track Pants
# Register ID= TSHFSPXRYRC4CKWT - Product Title: Solid Men Round Neck Yellow T-Shirt
# Register ID= TKPFZ3JRDVRHWSFY - Product Title: Solid Men Black Track Pants
# Register ID= TKPFYWGGFKZGUUEQ - Product Title: Solid Men Black Track Pants
# Register ID= TKPFMTHYHVABHKQA - Product Title: Solid Men Black Track Pants
# Register ID= TKPFHZH7CYDMURHX - Product Title: Solid Men Black Track Pants
# Register ID= TKPFZZB2TUEGQQSF - Product Title: Solid Men Black Track Pants
# Register ID= TKPFZNYQFG95PNCZ - Product Title: Solid Men Black Track Pants
# Register ID= TKPFX6ZY2QJAWUFH - Product Title: Solid Men Black Track Pants

# %%
# QUERY 4
query_4 = "Print stylish pyjama"
print(query_4)
docs = search(query_4, index)
top = 10

print("\n======================\nSample of {} results out of {} for the searched query:\n".format(min(top,len(docs)), len(docs)))
for d_id in docs[:top]:
    print("Register ID= {} - Product Title: {}".format(d_id, title_index[d_id]))
# Out:
# Print stylish pyjama
#
# ======================
# Sample of 10 results out of 16 for the searched query:
#
# Register ID= KTAFD3ZMPXPC3GE4 - Product Title: Women Printed Cotton Blend Straight Kurta  (Orange)
# Register ID= KTAFDVG4MFGKVFTE - Product Title: Men Printed Cotton Blend Straight Kurta  (Blue, Orange)
# Register ID= KTAFD3ZMEMREHQHS - Product Title: Women Printed Cotton Blend Straight Kurta  (Orange)
# Register ID= PYJFX5SSBZGHM2FU - Product Title: Men Pyjama  (Pack of 1)
# Register ID= PYJFX5SHQRGNYD7G - Product Title: Women Pyjama  (Pack of 1)
# Register ID= KTAFDVG4YZBS44WT - Product Title: Women Printed Cotton Blend Straight Kurta  (Blue, Orange)
# Register ID= PYJFX5SPDTCKQGUF - Product Title: Women Pyjama  (Pack of 1)
# Register ID= KTAFDVG4TF7ZFCQC - Product Title: Men Printed Cotton Blend Straight Kurta  (Blue, Orange)
# Register ID= PYJFX5SMJQ9WNUQA - Product Title: Women Pyjama  (Pack of 1)
# Register ID= KTAFBCFZCBYFGW8H - Product Title: Women Printed Cotton Blend Straight Kurta  (Multicolor)

# %%
# QUERY 5
query_5 = "Cycling Clothes in Black"
print(query_5)
docs = search(query_5, index)
top = 10

print("\n======================\nSample of {} results out of {} for the searched query:\n".format(min(top,len(docs)), len(docs)))
for d_id in docs[:top]:
    print("Register ID= {} - Product Title: {}".format(d_id, title_index[d_id]))
# Out:
# Cycling Clothes in Black
#
# ======================
# Sample of 10 results out of 45 for the searched query:
#
# Register ID= TSHE282KCQWXJUBD - Product Title: Solid Women Polo Neck Black T-Shirt
# Register ID= TSHFVG9U9G7AHC3P - Product Title: Solid Women Round Neck Multicolor T-Shirt  (Pack of 2)
# Register ID= TSHFVG9UY3EE97FE - Product Title: Solid Women Round Neck Multicolor T-Shirt  (Pack of 2)
# Register ID= SRTFW4GCKZGDPCHW - Product Title: Solid Women Black Swim Shorts
# Register ID= TSHFVG9URXUK3UKR - Product Title: Solid Men Round Neck Multicolor T-Shirt  (Pack of 2)
# Register ID= SRTFVXWH44WVYC3E - Product Title: Dyed Men Black Regular Shorts
# Register ID= TSHFVG9UFRWPM83U - Product Title: Solid Women Round Neck Multicolor T-Shirt  (Pack of 2)
# Register ID= TSHFVG9UHHUCUUEJ - Product Title: Solid Women Round Neck Multicolor T-Shirt  (Pack of 2)
# Register ID= TSHFVG9UUTZRPFH6 - Product Title: Solid Men Round Neck Multicolor T-Shirt  (Pack of 2)
# Register ID= TSHFVG9UQGFFVSZP - Product Title: Solid Men Round Neck Multicolor T-Shirt  (Pack of 2)

# %% [markdown]
# #### 1.3. Ranking of Results

# %%
def create_index_tfidf(dataset): # Create the index of the dataset
    num_registers = len(dataset)
    index = defaultdict(list)
    tf = defaultdict(dict)  # term -> {doc_id: tf}
    df = defaultdict(int)
    idf = defaultdict(float)
    title_index = {}

    for doc_id, row in dataset.iterrows():
        doc_id = row['pid']
        text = []
        for field in ['title', 'description', 'category', 'sub_category', 'brand', 'product_details', 'seller']:
            text.append(row[field])

        terms = build_terms(" ".join(text))
        title_index[doc_id] = row['title']

        current_page_index = {} # stores words and positions of CURRENT row
        for position, term in enumerate(terms):
            try:
                current_page_index[term][1].append(position)
            except KeyError:
                current_page_index[term] = [doc_id, [position]]

        # Compute norm for term frequency
        norm = math.sqrt(sum(len(posting[1])**2 for posting in current_page_index.values()))
        if norm == 0: norm = 1.0

        # Fill tf and df
        for term, posting in current_page_index.items():
            tf[term][doc_id] = len(posting[1]) / norm
            df[term] += 1

        # Merge with main index
        for term, posting in current_page_index.items():
            index[term].append(posting) # main index stores words and positions from ALL rows

    # Compute idf
    for term in df:
        idf[term] = math.log(num_registers / df[term])

    return index, tf, df, idf, title_index

def rank_documents(query_terms, candidate_docs, index, idf, tf, title_index):
    # Gives you a score for each term in the query parameter and obtains a document score used to order the documents by ranking
    doc_scores = {}

    # Build query vector (tf-idf)
    q_tf = Counter(query_terms)
    q_norm = math.sqrt(sum(freq**2 for freq in q_tf.values()))
    if q_norm == 0: q_norm = 1.0
    q_vec = {term: (freq / q_norm) * idf.get(term, 0) for term, freq in q_tf.items()}

    for doc_id in candidate_docs:
        score = 0.0
        for term in query_terms:
            if doc_id in tf.get(term, {}):
                score += tf[term][doc_id] * idf.get(term, 0) * q_vec.get(term, 0)
        doc_scores[doc_id] = score

    ranked_docs = sorted(doc_scores, key=doc_scores.get, reverse=True)
    return ranked_docs, doc_scores

def search_tf_idf(query, index, tf, idf, title_index):
    # Process a query, search for all the documents with the query terms, and call ranking function to rank them
    query = build_terms(query)

    term_docs = [posting[0] for posting in index[query[0]]]
    docs = set(term_docs)
    for term in query[1:]:
        try:
            # store in term_docs the ids of the docs that contain "term"
            term_docs = [posting[0] for posting in index[term]]

            # docs = docs ∩ term_docs (intersection)
            docs &= set(term_docs)
        except:
            # term is not in index
            pass
    docs = list(docs)
    ranked_docs,doc_scores = rank_documents(query, docs, index, idf, tf, title_index)

    return ranked_docs,doc_scores

# %%
index, tf, df, idf, title_index = create_index_tfidf(fashion_df)

# %%
# Interactive search
while True:
    query = input("\nEnter your search query (or type 'exit' to quit): ")
    if query.lower() == 'exit':
        print("Exiting search.")
        break

    # Search and rank documents
    ranked_docs, scores = search_tf_idf(query, index, tf, idf, title_index)

    if not ranked_docs:
        print("No results found for your query.")
        continue

    top = min(10, len(ranked_docs))
    docs = len(ranked_docs)

    print("\n======================")
    print("Sample of {} results out of {} for the searched query:\n".format(top, docs))

    # Display original titles ranked
    for rank, doc_id in enumerate(ranked_docs[:top], start=1):
        # original title from the dataset
        print(f"{rank}. {title_index[doc_id]}")


# Proposed queries to use:
    # query_1 = Comfort Women Dark Blue T-Shirt
    # query_2 = Green Stripe Men Cotton Polo
    # query_3 = Solid Track Black Pants for Men
    # query_4 = Print stylish pyjama
    # query_5 = Cycling Clothes in Black
# Out:
# Enter your search query (or type 'exit' to quit): Comfort Women Dark Blue T-Shirt
#
# ======================
# Sample of 10 results out of 111 for the searched query:
#
# 1. Solid Women Collared Neck Dark Blue, Maroon T-Shirt  (Pack of 2)
# 2. Solid Women Collared Neck Dark Blue, Yellow T-Shirt  (Pack of 2)
# 3. Solid Women Round Neck Dark Blue T-Shirt
# 4. Abstract Women Round Neck Dark Blue T-Shirt
# 5. Self Design Women Round Neck Dark Blue T-Shirt
# 6. Abstract Women Round Neck Dark Blue T-Shirt
# 7. Self Design Women Round Neck Dark Blue T-Shirt
# 8. Solid Women Polo Neck Dark Blue, Light Blue, Black T-Shirt  (Pack of 3)
# 9. Printed Women Round Neck Dark Blue T-Shirt
# 10. Printed Women Round Neck Dark Blue T-Shirt
#
# Enter your search query (or type 'exit' to quit): exit
# Exiting search.

# %% [markdown]
# ### **2. Evaluation**

# %% [markdown]
# #### 2.1. Evaluation Metrics

# %%
def precision_at_k(y_true, y_score, k=10):
  #Of what I retrieved, how much is relevant?
    '''
    Parameters
    ----------
    y_true: Ground truth (true relevance labels).
    y_score: Predicted scores.
    k : number of doc to consider.

    Returns
    -------
    precision @k : float

    '''
    order = np.argsort(y_score)[::-1]
    y_true = np.take(y_true, order[:k])
    relevant = np.sum(y_true == 1)
    return relevant/k

# %%
def recall_at_k(y_true, y_score, k=10):
  #Of what was relevant, how much did I retrieve?
    '''
    Parameters
    ----------
    y_true: Ground truth (true relevance labels).
    y_score: Predicted scores.
    k : number of doc to consider.

    Returns
    -------
    recall @k : float

    '''
    total_relevant = 0
    for val in y_true:
        if val == 1:
            total_relevant += 1

    if total_relevant == 0:
        return 0
    order = np.argsort(y_score)[::-1]
    y_true = np.take(y_true, order[:k])
    relevant = np.sum(y_true == 1)

    return relevant/total_relevant

# %%
def avg_precision_at_k(y_true, y_score, k=10):
  #How well the relevant documents are distributed among the top-k results.
    """
    Parameters
    ----------
    y_true: Ground truth (true relevance labels).
    y_score: Predicted scores.
    k : number of doc to consider.

    Returns
    -------
    average precision @k : float
    """

    order = np.argsort(y_score)[::-1]  # get the list of indexes of the predicted score sorted in descending order.

    prec_at_i = 0
    prec_at_i_list = []
    number_of_relevant = 0
    number_to_iterate = min(k, len(order))

    for i in range(number_to_iterate):
        if y_true[order[i]] == 1:
            number_of_relevant += 1
            prec_at_i = number_of_relevant / (i + 1)
            prec_at_i_list.append(prec_at_i)

    if number_of_relevant == 0:
        return 0
    else:
      return np.sum(prec_at_i_list) / number_of_relevant

# %%
def f1_at_k(y_true, y_score, k=10):
  #Harmonic mean of precision and recall. How good your ranking is for one query
  #F1=2×[(PrecisionxRecall)/(Precision+Recall)​]
  recall_at_k_result = recall_at_k(y_true, y_score, k)
  precision_at_k_result = precision_at_k(y_true, y_score, k)

  sum = recall_at_k_result + precision_at_k_result
  if sum == 0:
    return 0
  return 2 * (recall_at_k_result * precision_at_k_result) / sum

# %%
def map_at_k(search_res, k=10):
  #How good your system is overall across many queries
    '''
    Parameters
    ----------
    search_res: search results dataset containing:
        q_id: query id.
        doc_id: document id.
        predicted_relevance: relevance predicted through LightGBM.
        y_true: actual score of the document for the query (ground truth).

    Returns
    -------
    mean average precision @k : float
    '''
    avp = []
    for q in search_res["query_id"].unique():  #loop over all query id
        curr_data = search_res[search_res["query_id"] == q]  # select data for current query
        avp.append(avg_precision_at_k(np.array(curr_data["labels"]), np.array(curr_data["score"]),
                                      k))  #append average precision for current query
    return np.sum(avp) / len(avp)  # return mean average precision

# %%
def rr_at_k(y_true, y_score, k=10):
  #How high the first relevant item appears in the ranked list — averaged across many queries
  #MRR=1/Q​∑Q1/​(rq)​
    """
    Parameters
    ----------
    y_true: Ground truth (true relevance labels).
    y_score: Predicted scores.
    k : number of doc to consider.

    Returns
    -------
    Reciprocal Rank for current query
    """

    order = np.argsort(y_score)[::-1] # get the list of indexes of the predicted score sorted in descending order.
    y_true = np.take(y_true, order[:k]) # sort the actual relevance label of the documents based on predicted score(hint: np.take) and take first k.
    if sum(y_true==1) == 0: # if there are not relevant doument return 0
        return 0
    return 1 / (np.argmax(y_true == 1) + 1) # hint: to get the position of the first relevant document use "np.argmax"

# %%
def mrr_at_k(search_res, k=10):
  rr_scores = []
  for q in search_res['query_id'].unique():
      query_data = search_res[search_res['query_id'] == q]
      labels = np.array(query_data["labels"])
      scores = np.array(query_data["score"])

      rr_scores.append(rr_at_k(labels, scores, k))

  return np.sum(rr_scores) / len(rr_scores)

# %%
#How good the ranking order is, taking into account both relevance and position of results in the ranked list

def dcg_at_k(y_true, y_score, k=10):
    order = np.argsort(y_score)[::-1]  # get the list of indexes of the predicted score sorted in descending order.
    y_true = np.take(y_true, order[
                             :k])  # sort the actual relevance label of the documents based on predicted score(hint: np.take) and take first k.
    gain = 2 ** y_true - 1  # Compute gain (use formula 7 above)
    discounts = np.log2(np.arange(len(y_true)) + 2)  # Compute denominator
    return np.sum(gain / discounts)  #return dcg@k


def ndcg_at_k(y_true, y_score, k=10):
    dcg_max = dcg_at_k(y_true, y_true, k)
    if not dcg_max:
        return 0
    return np.round(dcg_at_k(y_true, y_score, k) / dcg_max, 4)

# %% [markdown]
# #### 2.2. Evaluation on Validation Data

# %%
# Queries
queries = {1: "women full sleeve sweatshirt cotton", 2: "men slim jeans blue"}

results = list()
for query_id, query_text in queries.items(): #for each query
    ranked_docs, doc_scores = search_tf_idf(query_text, index, tf, idf, title_index) #we compute the tfidf scores
    for doc_id, row in val_df[val_df['query_id'] == query_id].iterrows():
        score = doc_scores.get(doc_id, 0)
        results.append([doc_id, query_id, score, row['labels']])

final_df = pd.DataFrame(results, columns=['doc_id', 'query_id', 'score', 'labels'])

# %%
k = [4, 8, 12, 16, 20]
for k_j in k:
  mrr_list = list()
  ndcg_list = list()
  print("\n======================")
  for query_id, query_text in queries.items():
    print("\nValidation Metrics of query {}: '{}', for k = {} :".format(query_id, query_text, k_j))

    result = final_df[final_df["query_id"] == query_id]
    labels = result["labels"].to_list()
    scores = result["score"].to_list()

    print(f"Precision@{k_j}: {precision_at_k(labels, scores, k_j):.3f}")
    print(f"Recall@{k_j}: {recall_at_k(labels, scores, k_j):.3f}")
    print(f"Average Precision@{k_j}: {avg_precision_at_k(labels, scores, k_j):.3f}")
    print(f"F1-Score@{k_j}: {f1_at_k(labels, scores, k_j):.3f}")
    print(f"Normalized Discounted Cumulative Gain@{k_j}: {ndcg_at_k(labels, scores, k_j):.3f}")
    mrr_list.append(rr_at_k(labels, scores, k_j))

  print("\nValidation Metrics of both queries:")
  print(f"Mean Average Precision@{k_j}: {map_at_k(final_df, k_j):.3f}")
  print(f"Mean Reciprocal Rank@{k_j}: {np.mean(mrr_list):.3f}")
# Out:
# ======================
#
# Validation Metrics of query 1: 'women full sleeve sweatshirt cotton', for k = 4 :
# Precision@4: 0.750
# Recall@4: 0.231
# Average Precision@4: 0.639
# F1-Score@4: 0.353
# Normalized Discounted Cumulative Gain@4: 0.610
#
# Validation Metrics of query 2: 'men slim jeans blue', for k = 4 :
# Precision@4: 0.250
# Recall@4: 0.100
# Average Precision@4: 0.250
# F1-Score@4: 0.143
# Normalized Discounted Cumulative Gain@4: 0.168
#
# Validation Metrics of both queries:
# Mean Average Precision@4: 0.444
# Mean Reciprocal Rank@4: 0.375
#
# ======================
#
# Validation Metrics of query 1: 'women full sleeve sweatshirt cotton', for k = 8 :
# Precision@8: 0.625
# Recall@8: 0.385
# Average Precision@8: 0.710
# F1-Score@8: 0.476
# Normalized Discounted Cumulative Gain@8: 0.583
#
# Validation Metrics of query 2: 'men slim jeans blue', for k = 8 :
# Precision@8: 0.500
# Recall@8: 0.400
# Average Precision@8: 0.430
# F1-Score@8: 0.444
# Normalized Discounted Cumulative Gain@8: 0.381
#
# Validation Metrics of both queries:
# Mean Average Precision@8: 0.570
# Mean Reciprocal Rank@8: 0.375
#
# ======================
#
# Validation Metrics of query 1: 'women full sleeve sweatshirt cotton', for k = 12 :
# Precision@12: 0.667
# Recall@12: 0.615
# Average Precision@12: 0.682
# F1-Score@12: 0.640
# Normalized Discounted Cumulative Gain@12: 0.617
#
# Validation Metrics of query 2: 'men slim jeans blue', for k = 12 :
# Precision@12: 0.417
# Recall@12: 0.500
# Average Precision@12: 0.435
# F1-Score@12: 0.455
# Normalized Discounted Cumulative Gain@12: 0.393
#
# Validation Metrics of both queries:
# Mean Average Precision@12: 0.558
# Mean Reciprocal Rank@12: 0.375
#
# ======================
#
# Validation Metrics of query 1: 'women full sleeve sweatshirt cotton', for k = 16 :
# Precision@16: 0.625
# Recall@16: 0.769
# Average Precision@16: 0.681
# F1-Score@16: 0.690
# Normalized Discounted Cumulative Gain@16: 0.683
#
# Validation Metrics of query 2: 'men slim jeans blue', for k = 16 :
# Precision@16: 0.500
# Recall@16: 0.800
# Average Precision@16: 0.446
# F1-Score@16: 0.615
# Normalized Discounted Cumulative Gain@16: 0.558
#
# Validation Metrics of both queries:
# Mean Average Precision@16: 0.564
# Mean Reciprocal Rank@16: 0.375
#
# ======================
#
# Validation Metrics of query 1: 'women full sleeve sweatshirt cotton', for k = 20 :
# Precision@20: 0.650
# Recall@20: 1.000
# Average Precision@20: 0.675
# F1-Score@20: 0.788
# Normalized Discounted Cumulative Gain@20: 0.814
#
# Validation Metrics of query 2: 'men slim jeans blue', for k = 20 :
# Precision@20: 0.500
# Recall@20: 1.000
# Average Precision@20: 0.460
# F1-Score@20: 0.667
# Normalized Discounted Cumulative Gain@20: 0.661
#
# Validation Metrics of both queries:
# Mean Average Precision@20: 0.568
# Mean Reciprocal Rank@20: 0.375

# %% [markdown]
# #### 2.3 Evaluation on our Queries

# %%
vocab = list(tf.keys())
docs = list(title_index.keys())

# Construct the matrix with tf-idf
tfidf_matrix = pd.DataFrame(0.0, index=docs, columns=vocab)

for term in vocab:
    for doc_id, tf_value in tf[term].items():
        tfidf_matrix.loc[doc_id, term] = tf_value * idf[term]

# %%
def query_to_vector(query, vocab, idf):
    terms = build_terms(query)

    # Compute raw term frequencies for the query
    tf_query = {}
    for term in terms:
        if term in vocab:
            tf_query[term] = tf_query.get(term, 0) + 1

    # Normalize term frequency like in create_index_tfidf()
    norm = math.sqrt(sum(tf**2 for tf in tf_query.values()))
    if norm == 0:
        norm = 1.0

    vector = np.zeros(len(vocab))
    for i, term in enumerate(vocab):
        if term in terms:
            vector[i] = tf_query[term]/norm * idf.get(term, 0)
    return vector

# %%
queries = {1: "Comfort Women Dark Blue T-Shirt",
           2: "Green Stripe Men Cotton Polo",
           3: "Solid Track Black Pants for Men",
           4: "Print stylish pyjama",
           5: "Cycling Clothes in Black"
           }

# We create the queries matrix
query_vectors = np.array([query_to_vector(q_name, vocab, idf) for q_id, q_name in queries.items()])

# Document matrix
doc_vectors = tfidf_matrix.values

# Compute cosine similarity between the docs and the queries
similarity_matrix = cosine_similarity(query_vectors, doc_vectors)

similarity_df = pd.DataFrame(
    similarity_matrix.T,
    index=docs,
    columns=queries
)

# %%
# Assign the relevance label (1) to the documents with cosine similarity >= 0.2
threshold = 0.2
validation_data = []

for q_id, q_name in queries.items():
    for j, doc_id in enumerate(docs):
        sim = similarity_matrix[q_id-1, j]
        label = 1 if sim >= threshold else 0
        validation_data.append({
            "pid": doc_id,
            "title": title_index[doc_id],
            "query_id": q_id,
            "labels": label
        })

new_validation_df = pd.DataFrame(validation_data)

# %%
results = list()
for query_id, query_text in queries.items(): # For each query
    ranked_docs, doc_scores = search_tf_idf(query_text, index, tf, idf, title_index) # We compute the tfidf scores
    for doc_id, row in new_validation_df[new_validation_df['query_id'] == query_id].iterrows():
        doc_id = row['pid']
        score = doc_scores.get(doc_id, 0)
        title = title_index[doc_id]
        results.append([doc_id, title, query_id, score, row['labels']])

final_df = pd.DataFrame(results, columns=['pid', 'title', 'query_id', 'score', 'labels'])

# %%
final_df.labels.value_counts()
# Out:
# labels
# 0    136555
# 1      3845
# Name: count, dtype: int64

# %%
k = [50, 100, 200, 500]

for k_j in k:
  mrr_list = list()
  ndcg_list = list()
  print("\n======================")
  for query_id, query_text in queries.items():
    print("\nValidation Metrics of query {}: '{}', for k = {} :".format(query_id, query_text, k_j))

    result = final_df[final_df["query_id"] == query_id]
    labels = result["labels"].to_list()
    scores = result["score"].to_list()

    print(f"Precision@{k_j}: {precision_at_k(labels, scores, k_j):.3f}")
    print(f"Recall@{k_j}: {recall_at_k(labels, scores, k_j):.3f}")
    print(f"Average Precision@{k_j}: {avg_precision_at_k(labels, scores, k_j):.3f}")
    print(f"F1-Score@{k_j}: {f1_at_k(labels, scores, k_j):.3f}")
    print(f"Normalized Discounted Cumulative Gain@{k_j}: {ndcg_at_k(labels, scores, k_j):.3f}")
    mrr_list.append(rr_at_k(labels, scores, k_j))

  print("\nValidation Metrics of all queries:")
  print(f"Mean Average Precision@{k_j}: {map_at_k(final_df, k_j):.3f}")
  print(f"Mean Reciprocal Rank@{k_j}: {np.mean(mrr_list):.3f}")
# Out:
# ======================
#
# Validation Metrics of query 1: 'Comfort Women Dark Blue T-Shirt', for k = 50 :
# Precision@50: 0.420
# Recall@50: 0.031
# Average Precision@50: 0.864
# F1-Score@50: 0.058
# Normalized Discounted Cumulative Gain@50: 0.544
#
# Validation Metrics of query 2: 'Green Stripe Men Cotton Polo', for k = 50 :
# Precision@50: 0.440
# Recall@50: 0.012
# Average Precision@50: 1.000
# F1-Score@50: 0.022
# Normalized Discounted Cumulative Gain@50: 0.580
#
# Validation Metrics of query 3: 'Solid Track Black Pants for Men', for k = 50 :
# Precision@50: 1.000
# Recall@50: 0.052
# Average Precision@50: 1.000
# F1-Score@50: 0.098
# Normalized Discounted Cumulative Gain@50: 1.000
#
# Validation Metrics of query 4: 'Print stylish pyjama', for k = 50 :
# Precision@50: 0.140
# Recall@50: 0.025
# Average Precision@50: 1.000
# F1-Score@50: 0.043
# Normalized Discounted Cumulative Gain@50: 0.282
#
# Validation Metrics of query 5: 'Cycling Clothes in Black', for k = 50 :
# Precision@50: 0.160
# Recall@50: 0.444
# Average Precision@50: 0.724
# F1-Score@50: 0.235
# Normalized Discounted Cumulative Gain@50: 0.539
#
# Validation Metrics of all queries:
# Mean Average Precision@50: 0.918
# Mean Reciprocal Rank@50: 1.000
#
# ======================
#
# Validation Metrics of query 1: 'Comfort Women Dark Blue T-Shirt', for k = 100 :
# Precision@100: 0.220
# Recall@100: 0.033
# Average Precision@100: 0.844
# F1-Score@100: 0.057
# Normalized Discounted Cumulative Gain@100: 0.344
#
# Validation Metrics of query 2: 'Green Stripe Men Cotton Polo', for k = 100 :
# Precision@100: 0.220
# Recall@100: 0.012
# Average Precision@100: 1.000
# F1-Score@100: 0.022
# Normalized Discounted Cumulative Gain@100: 0.357
#
# Validation Metrics of query 3: 'Solid Track Black Pants for Men', for k = 100 :
# Precision@100: 1.000
# Recall@100: 0.103
# Average Precision@100: 1.000
# F1-Score@100: 0.187
# Normalized Discounted Cumulative Gain@100: 1.000
#
# Validation Metrics of query 4: 'Print stylish pyjama', for k = 100 :
# Precision@100: 0.070
# Recall@100: 0.025
# Average Precision@100: 1.000
# F1-Score@100: 0.037
# Normalized Discounted Cumulative Gain@100: 0.174
#
# Validation Metrics of query 5: 'Cycling Clothes in Black', for k = 100 :
# Precision@100: 0.080
# Recall@100: 0.444
# Average Precision@100: 0.724
# F1-Score@100: 0.136
# Normalized Discounted Cumulative Gain@100: 0.539
#
# Validation Metrics of all queries:
# Mean Average Precision@100: 0.914
# Mean Reciprocal Rank@100: 1.000
#
# ======================
#
# Validation Metrics of query 1: 'Comfort Women Dark Blue T-Shirt', for k = 200 :
# Precision@200: 0.215
# Recall@200: 0.064
# Average Precision@200: 0.540
# F1-Score@200: 0.098
# Normalized Discounted Cumulative Gain@200: 0.290
#
# Validation Metrics of query 2: 'Green Stripe Men Cotton Polo', for k = 200 :
# Precision@200: 0.110
# Recall@200: 0.012
# Average Precision@200: 1.000
# F1-Score@200: 0.021
# Normalized Discounted Cumulative Gain@200: 0.215
#
# Validation Metrics of query 3: 'Solid Track Black Pants for Men', for k = 200 :
# Precision@200: 0.675
# Recall@200: 0.139
# Average Precision@200: 0.988
# F1-Score@200: 0.231
# Normalized Discounted Cumulative Gain@200: 0.746
#
# Validation Metrics of query 4: 'Print stylish pyjama', for k = 200 :
# Precision@200: 0.035
# Recall@200: 0.025
# Average Precision@200: 1.000
# F1-Score@200: 0.029
# Normalized Discounted Cumulative Gain@200: 0.104
#
# Validation Metrics of query 5: 'Cycling Clothes in Black', for k = 200 :
# Precision@200: 0.040
# Recall@200: 0.444
# Average Precision@200: 0.724
# F1-Score@200: 0.073
# Normalized Discounted Cumulative Gain@200: 0.539
#
# Validation Metrics of all queries:
# Mean Average Precision@200: 0.850
# Mean Reciprocal Rank@200: 1.000
#
# ======================
#
# Validation Metrics of query 1: 'Comfort Women Dark Blue T-Shirt', for k = 500 :
# Precision@500: 0.138
# Recall@500: 0.102
# Average Precision@500: 0.413
# F1-Score@500: 0.117
# Normalized Discounted Cumulative Gain@500: 0.189
#
# Validation Metrics of query 2: 'Green Stripe Men Cotton Polo', for k = 500 :
# Precision@500: 0.064
# Recall@500: 0.017
# Average Precision@500: 0.716
# F1-Score@500: 0.027
# Normalized Discounted Cumulative Gain@500: 0.123
#
# Validation Metrics of query 3: 'Solid Track Black Pants for Men', for k = 500 :
# Precision@500: 0.288
# Recall@500: 0.149
# Average Precision@500: 0.954
# F1-Score@500: 0.196
# Normalized Discounted Cumulative Gain@500: 0.383
#
# Validation Metrics of query 4: 'Print stylish pyjama', for k = 500 :
# Precision@500: 0.014
# Recall@500: 0.025
# Average Precision@500: 1.000
# F1-Score@500: 0.018
# Normalized Discounted Cumulative Gain@500: 0.081
#
# Validation Metrics of query 5: 'Cycling Clothes in Black', for k = 500 :
# Precision@500: 0.016
# Recall@500: 0.444
# Average Precision@500: 0.724
# F1-Score@500: 0.031
# Normalized Discounted Cumulative Gain@500: 0.539
#
# Validation Metrics of all queries:
# Mean Average Precision@500: 0.762
# Mean Reciprocal Rank@500: 1.000

# %% [markdown]
# ## **Part 3: Ranking and Filtering**

# %% [markdown]
# ### **1. Different ways of ranking**

# %%
# Function to get the candidate docs before ranking
def conjunctive_search_terms(query, index, build_terms_fn=build_terms):
    """Return list of doc_ids that contain ALL query terms (using stemmed tokens)."""
    terms = build_terms_fn(query)
    if not terms:
      return []

    # Start with postings of first term
    first = terms[0]
    try:
      docs = set(posting[0] for posting in index[first])
    except KeyError:
      return []

    # Iterate through all query terms and find the docs that contain all terms
    for t in terms[1:]:
      try:
        docs &= set(posting[0] for posting in index[t])
      except KeyError:
        return []
    return list(docs)

# %% [markdown]
# #### 1.1. TF-IDF + cosine similarity:

# %%
from math import log, sqrt
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity

def tfidf_cosine_rank(query, docs, tf, idf, index, title_index, vocab, build_terms_fn=build_terms, top_k=20):
    """Rank documents using cosine similarity over TF-IDF vectors"""

    # Build query vector
    query_vector = query_to_vector(query, vocab, idf).reshape(1, -1)

    # Build TF-IDF matrix for documents that have all query terms
    tfidf_matrix = np.zeros((len(docs), len(vocab)))
    for i, term in enumerate(vocab):
      for j, doc_id in enumerate(docs):
        if doc_id in tf[term].keys():
          tf_value = tf[term][doc_id]
          tfidf_matrix[j, i] = tf_value * idf[term]

    # Compute cosine similarity
    similarity_scores = cosine_similarity(query_vector, tfidf_matrix).flatten()

    scores = {key: score for key, score in zip(docs, similarity_scores)}
    ranked = sorted(scores.items(), key=lambda x: x[1], reverse=True)[:top_k]
    return ranked, scores

# %% [markdown]
# #### 1.2. BM25
# ![Captura de pantalla 2025-11-12 a las 18.59.47.png](data:image/png;base64,...)

# %%
# Function to compute the length of all documents
def compute_doc_lengths_from_tf(tf):
    """
    Count number of words given the TF dictionary with the following format:
      tf: term -> {doc_id: tf}
    """
    doc_lengths = defaultdict(int)
    for t, posting in tf.items():
      for d, freq in posting.items():
        doc_lengths[d] += freq
    return doc_lengths

# %%
def bm25_rank(query, docs, index, tf, idf, doc_lengths=None, k1=1.5, b=0.75, top_k=20, build_terms_fn=build_terms):
    """Rank documents using BM25"""
    # Process query
    terms = build_terms_fn(query)
    if not terms:
      return [], {}

    # Compute length of all documents
    if doc_lengths is None:
      doc_lengths = compute_doc_lengths_from_tf(tf)

    # Find average doc length
    avgdl = np.mean(list(doc_lengths.values())) if doc_lengths else 1.0

    # Compute BM25 score
    scores = defaultdict(float)
    N = len(doc_lengths)
    for t in terms:
      # df_t = document frequency for a term (number of docs containing the term)
      postings = index.get(t, [])
      df_t = len(postings)
      # If there are 0 postings, skip the following code and start again with next term t
      if df_t == 0:
        continue
      # IDF is used in BM25 (with small smoothing)
      idf_bm25 = max(0.0, log((N - df_t + 0.5) / (df_t + 0.5) + 1e-9))

      for doc_id, *rest in postings:
        if doc_id not in docs:
          continue
        f = tf[t].get(doc_id, 0)
        denom = f + k1 * (1 - b + b * (doc_lengths.get(doc_id, 0) / avgdl))
        score = idf_bm25 * ((f * (k1 + 1)) / (denom + 1e-9))
        scores[doc_id] += score

    ranked = sorted(scores.items(), key=lambda x: x[1], reverse=True)[:top_k]
    return ranked, scores

# %% [markdown]
# #### 1.3. Our Score

# %%
# Function to normalize numerical values with min-max scaling
def min_max_scaling(fashion_df, doc_id, common_docs, value):
    min_value = fashion_df[value].min()
    max_value = fashion_df[value].max()

    return (fashion_df.loc[fashion_df["pid"] == doc_id, value] - min_value) / (max_value - min_value)

# %%
# Function to compute number of words in the title that appear in the query
def processing_title(title, query):
    """
    Count number of words in the title that appear in the query considering the
    importance of the word (which is the number of times it appears in the query)
    Example:
        >>> processing_title(['red', 'comfort', 'round', 'neck', 'tshirt'],
                            ['red', 'tshirt', 'red'])
        3
    """
    title_vec = np.array(title)
    query_vec = np.array(query)

    # Iterate through all title terms
    counter = 0
    for t in title_vec:
      # If t appears in the query, add the number of times it appears:
      # If word 'red' appears once, it will add 1 but if it appears twice in the query, it adds 2
      if t in query_vec:
        positions = np.where(query_vec==t)[0]
        counter += len(positions)
    return counter

# %%
def ourscore_cosine(query, inverted_index, docs, vocab, fashion_df, idf, tf, top_k=20, build_terms_fn=build_terms):
    """
    Rank documents considering numerical variables like 'actual_price', 'average_rating', 'discount'
    and 'out_of_stock' with dot products. Take into account also words in the title that appear in the query.
    """
    # Build query vector
    query_vector = query_to_vector(query, vocab, idf).reshape(1, -1)

    # Build TF-IDF matrix for documents that have all query terms
    tfidf_matrix = np.zeros((len(docs), len(vocab)))
    for i, term in enumerate(vocab):
      for j, doc_id in enumerate(docs):
        if doc_id in tf[term].keys():
          tf_value = tf[term][doc_id]
          tfidf_matrix[j, i] = tf_value * idf[term]

    # Vector dot products (numerator of cosine similarity formula)
    dot_products = tfidf_matrix.dot(query_vector.T).flatten()

    # Load dataset and store the values of the chosen numerical variables as arrays
    df_indexed = fashion_df.set_index("pid").loc[docs]

    actual_price_vec = df_indexed["actual_price"].to_numpy()
    avg_rating_vec = df_indexed["average_rating"].to_numpy()
    discount_vec = df_indexed["discount"].to_numpy()
    out_of_stock_vec = df_indexed["out_of_stock"].to_numpy().astype(bool)

    # Compute query terms occurrences in the title for every document
    processed_query = build_terms_fn(query)
    in_title = df_indexed["title"].apply(lambda x: processing_title(x, query=processed_query)).to_numpy()

    # Min-max scaling for all vectors
    actual_price_vec = (actual_price_vec - actual_price_vec.min()) / (actual_price_vec.max() - actual_price_vec.min())
    avg_rating_vec = (avg_rating_vec - avg_rating_vec.min()) / (avg_rating_vec.max() - avg_rating_vec.min())
    discount_vec = (discount_vec - discount_vec.min()) / (discount_vec.max() - discount_vec.min())

    title_vec = np.zeros(len(in_title))
    if in_title.max() != in_title.min():
      title_vec = (in_title - in_title.min()) / (in_title.max() - in_title.min())

    # Final scoring: basic score is the dot product (cosine without normalization) and the query frequency in the title
    # If the product is not out_of_stock, then we consider numerical variables like 'actual_price', 'average_rating' and 'discount'
    bonus_title = 0.3 * title_vec
    base = 0.5 * dot_products + bonus_title
    bonus = 0.2 * (discount_vec*0.6 + avg_rating_vec*0.6 - actual_price_vec*0.2)

    scores_vec = np.where(out_of_stock_vec, base, base + bonus)

    # Convert scores to dictionary and sort the documents
    scores = dict(zip(docs, scores_vec))
    ranked = sorted(scores.items(), key=lambda x: x[1], reverse=True)[:top_k]

    return ranked, scores

# %% [markdown]
# #### 1.4 Comparison between scores

# %%
fashion_df_2 = fashion_df_processed.copy()

# Process "average rating", "actual price" and "discount" in order to work with the values as expected (like numbers)
fashion_df_2.loc[(fashion_df_2["average_rating"] == ""), "average_rating"] = fashion_df_2.loc[(fashion_df_2["average_rating"] == ""), "average_rating"].str.replace("", "0").astype(float)
fashion_df_2.loc[~(fashion_df_2["average_rating"] == ""), "average_rating"] = fashion_df_2.loc[~(fashion_df_2["average_rating"] == ""), "average_rating"].fillna("0").astype(float)

fashion_df_2.loc[(fashion_df_2["actual_price"] == ""), "actual_price"] = fashion_df_2.loc[(fashion_df_2["actual_price"] == ""), "actual_price"].str.replace("", "0").astype(float)
fashion_df_2.loc[~(fashion_df_2["actual_price"] == ""), "actual_price"] = fashion_df_2.loc[~(fashion_df_2["actual_price"] == ""), "actual_price"].str.replace(",", ".").fillna("0").astype(float)

fashion_df_2.loc[(fashion_df_2["discount"] == ""), "discount"] = fashion_df_2.loc[(fashion_df_2["discount"] == ""), "discount"].str.replace("", "0").astype(float)
fashion_df_2.loc[~(fashion_df_2["discount"] == ""), "discount"] = fashion_df_2.loc[~(fashion_df_2["discount"] == ""), "discount"].str.replace("%", "") .str.replace("off", "").str.strip().fillna("0").astype(float)

# %%
vocab = list(tf.keys())

while True:
    q = input("\nEnter your query (or type 'exit' to quit): ").strip()
    if q.lower() == "exit":
        print("Exiting search test.")
        break

    # Get docs with AND semantics
    docs = conjunctive_search_terms(q, index)
    if not docs:
        print("No documents found containing all query terms.")
        continue

    # TF-IDF + cosine
    ranked_tfidf, _ = tfidf_cosine_rank(q, docs, tf, idf, index, title_index, vocab, top_k=5)
    print("\nTop 5 by TF-IDF + cosine:")
    for i, (doc_id, score) in enumerate(ranked_tfidf, 1):
        title = fashion_df.loc[fashion_df["pid"] == doc_id, "title"].values
        title = title[0] if len(title) else "(no title)"
        print(f"{i:2d}. {doc_id}  score={score:.4f}  {title}")

    # BM25
    ranked_bm25, _ = bm25_rank(q, docs, index, tf, idf, top_k=5)
    print("\nTop 5 by BM25:")
    for i, (doc_id, score) in enumerate(ranked_bm25, 1):
        title = fashion_df.loc[fashion_df["pid"] == doc_id, "title"].values
        title = title[0] if len(title) else "(no title)"
        print(f"{i:2d}. {doc_id}  score={score:.4f}  {title}")


    # Our Score
    ranked_ourscore, _ = ourscore_cosine(q, index, docs, vocab, fashion_df_2, idf, tf, top_k=5)
    print("\nTop 5 by Our Score:")
    for i, (doc_id, score) in enumerate(ranked_ourscore, 1):
        title = fashion_df.loc[fashion_df["pid"] == doc_id, "title"].values
        title = title[0] if len(title) else "(no title)"
        print(f"{i:2d}. {doc_id}  score={score:.4f}  {title}")

# Examples of queries to process:
    # query_1 = Comfort Women Dark Blue T-Shirt
    # query_2 = Green Stripe Men Cotton Polo
    # query_3 = Solid Track Black Pants for Men
    # query_4 = Print stylish pyjama
    # query_5 = Cycling Clothes in Black
# Out:
# Enter your query (or type 'exit' to quit): Comfort Women Dark Blue T-Shirt
#
# Top 5 by TF-IDF + cosine:
#  1. TSHFPNRFYBMKHSGK  score=0.3661  Solid Women Collared Neck Blue T-Shirt
#  2. TSHFXZSHHJWFGWNU  score=0.3236  Solid Women Collared Neck Dark Blue, Yellow T-Shirt  (Pack of 2)
#  3. TSHFGJBYWW425HFP  score=0.3225  Self Design Women Round Neck Dark Blue T-Shirt
#  4. TSHFGJBYQWQAA5ZN  score=0.3210  Self Design Women Round Neck Dark Blue T-Shirt
#  5. TSHFXZSHYWFBU2HM  score=0.3185  Solid Women Collared Neck Dark Blue, Maroon T-Shirt  (Pack of 2)
#
# Top 5 by BM25:
#  1. TSHFXZSHHJWFGWNU  score=1.2909  Solid Women Collared Neck Dark Blue, Yellow T-Shirt  (Pack of 2)
#  2. TSHFXZSHYWFBU2HM  score=1.2909  Solid Women Collared Neck Dark Blue, Maroon T-Shirt  (Pack of 2)
#  3. TSHFGJB5BMWGRXXC  score=1.1406  Abstract Women Round Neck Dark Blue T-Shirt
#  4. TSHF34PEWJWG5ZTN  score=1.1303  Solid Women Round Neck Dark Blue T-Shirt
#  5. TSHFGJBYWW425HFP  score=1.1201  Self Design Women Round Neck Dark Blue T-Shirt
#
# Top 5 by Our Score:
#  1. TSHFZWRT2KTZJ7BK  score=0.8153  Solid Women Round Neck Maroon, Blue, Light Blue, Dark Blue, Black T-Shirt  (Pack of 5)
#  2. TSHFXZSHHJWFGWNU  score=0.8089  Solid Women Collared Neck Dark Blue, Yellow T-Shirt  (Pack of 2)
#  3. TSHFXZSHYWFBU2HM  score=0.8089  Solid Women Collared Neck Dark Blue, Maroon T-Shirt  (Pack of 2)
#  4. TSHEANKUTX7DQZJA  score=0.8086  Solid Women Polo Neck Dark Blue, Light Blue, Black T-Shirt  (Pack of 3)
#  5. TSHFGBY8CEWZGAVH  score=0.7995  Self Design, Solid Women Polo Neck Dark Blue, Light Blue, Blue T-Shirt  (Pack of 3)
#
# Enter your query (or type 'exit' to quit): Green Stripe Men Cotton Polo
#
# Top 5 by TF-IDF + cosine:
#  1. TSHFY8MJHZ6WZYME  score=0.7612  Striped Men Polo Neck Multicolor T-Shirt
#  2. TSHEUUPDTD5AKZP2  score=0.5989  Striped Men Polo Neck Green T-Shirt
#  3. TSHFPKNCFHB6QTFP  score=0.5976  Striped Men Polo Neck Green, Blue T-Shirt
#  4. TSHFYN62TKXBUFWG  score=0.5965  Striped Men Polo Neck Blue, Green, White T-Shirt
#  5. TSHEU7DUUNJ8ASQ4  score=0.5821  Striped Men Polo Neck Green T-Shirt
#
# Top 5 by BM25:
#  1. TSHFQEEQ2HA3EX96  score=2.8406  Striped Men Polo Neck Green T-Shirt
#  2. TSHFY8MJHZ6WZYME  score=2.8293  Striped Men Polo Neck Multicolor T-Shirt
#  3. TSHFYN62TKXBUFWG  score=2.7996  Striped Men Polo Neck Blue, Green, White T-Shirt
#  4. TSHFPKNCFHB6QTFP  score=2.7964  Striped Men Polo Neck Green, Blue T-Shirt
#  5. TSHEUUPDTD5AKZP2  score=2.6034  Striped Men Polo Neck Green T-Shirt
#
# Top 5 by Our Score:
#  1. TSHFQEEQ2HA3EX96  score=1.7226  Striped Men Polo Neck Green T-Shirt
#  2. TSHEUUPDTD5AKZP2  score=1.6022  Striped Men Polo Neck Green T-Shirt
#  3. TSHFPKNCFHB6QTFP  score=1.5495  Striped Men Polo Neck Green, Blue T-Shirt
#  4. TSHFYN62TKXBUFWG  score=1.5294  Striped Men Polo Neck Blue, Green, White T-Shirt
#  5. TSHEU7DUUNJ8ASQ4  score=1.5084  Striped Men Polo Neck Green T-Shirt
#
# Enter your query (or type 'exit' to quit): Solid Track Black Pants for Men
#
# Top 5 by TF-IDF + cosine:
#  1. TKPFRR83HRGAYYJ6  score=0.7436  Solid Men Black Track Pants
#  2. TKPFRR83YNVYCUPN  score=0.7436  Solid Men Black Track Pants
#  3. TKPFRR83TFTU9TDV  score=0.7436  Solid Men Black Track Pants
#  4. TKPFYHVE7SZNHTMR  score=0.7268  Solid Men Black, Blue Track Pants
#  5. TKPF3FPZRRJUWTAZ  score=0.7120  Solid Men Blue, Black Track Pants
#
# Top 5 by BM25:
#  1. TKPFZMZSWZN5HKEZ  score=4.4082  Solid Men Black Track Pants
#  2. TKPFRR83YNVYCUPN  score=4.1616  Solid Men Black Track Pants
#  3. TKPFRR83HRGAYYJ6  score=4.1616  Solid Men Black Track Pants
#  4. TKPFRR83TFTU9TDV  score=4.1616  Solid Men Black Track Pants
#  5. TKPEYQ6YNHW8FV5R  score=3.8420  Solid Men Black, Orange Track Pants
#
# Top 5 by Our Score:
#  1. TKPF3FPKTYM55SAV  score=2.1908  Solid Men Black, Grey Track Pants
#  2. TKPF3FPZRRJUWTAZ  score=2.1908  Solid Men Blue, Black Track Pants
#  3. TKPF3FPQGCHXHGRM  score=2.1908  Solid Men Black, Grey Track Pants
#  4. TKPF3FPNZ5XCHZ6R  score=2.1908  Solid Men Black, Grey Track Pants
#  5. TKPF3FPKHNWZ3UMG  score=2.1908  Solid Men Blue, Black Track Pants
#
# Enter your query (or type 'exit' to quit): Print stylish pyjama
#
# Top 5 by TF-IDF + cosine:
#  1. PYJFX5SMJQ9WNUQA  score=0.5180  Women Pyjama  (Pack of 1)
#  2. PYJFX5SPDTCKQGUF  score=0.5180  Women Pyjama  (Pack of 1)
#  3. PYJFX5SHQRGNYD7G  score=0.5167  Women Pyjama  (Pack of 1)
#  4. PYJFX5SSBZGHM2FU  score=0.5157  Men Pyjama  (Pack of 1)
#  5. PYJFX5SPGAF8E49C  score=0.5156  Women Pyjama  (Pack of 1)
#
# Top 5 by BM25:
#  1. PYJFX5SPDTCKQGUF  score=2.7171  Women Pyjama  (Pack of 1)
#  2. PYJFX5SUNQGAFZ96  score=2.7171  Women Pyjama  (Pack of 1)
#  3. PYJFX5SMJQ9WNUQA  score=2.7171  Women Pyjama  (Pack of 1)
#  4. PYJFX5SHQRGNYD7G  score=2.7171  Women Pyjama  (Pack of 1)
#  5. PYJFX5SVGHKJ9UQN  score=2.6796  Men Pyjama  (Pack of 1)
#
# Top 5 by Our Score:
#  1. PYJFX5SMJQ9WNUQA  score=2.2562  Women Pyjama  (Pack of 1)
#  2. PYJFX5SHQRGNYD7G  score=2.2562  Women Pyjama  (Pack of 1)
#  3. PYJFX5SPDTCKQGUF  score=2.2562  Women Pyjama  (Pack of 1)
#  4. PYJFX5SUNQGAFZ96  score=2.2562  Women Pyjama  (Pack of 1)
#  5. PYJFX5SPGAF8E49C  score=2.2384  Women Pyjama  (Pack of 1)
#
# Enter your query (or type 'exit' to quit): Cycling Clothes in Black
#
# Top 5 by TF-IDF + cosine:
#  1. TKPE7KJ9FZWSUFNF  score=0.4616  cycling Solid Men Black Track Pants
#  2. TGTFDT8EZZNMZUZR  score=0.3559  Solid Women Black Cycling Shorts
#  3. SRTEDGDPFYDQXNJF  score=0.2560  Solid Women Black Running Shorts
#  4. TSHE282ZMAPEWZ6Z  score=0.2481  Solid Women Polo Neck Black T-Shirt
#  5. SRTEQKY62CMVFZNY  score=0.2279  Solid Men Black Beach Shorts, Gym Shorts, Night Shorts, Basic Shorts, Running Shorts, Boxer Shorts, Sports Shorts, Cycling Shorts
#
# Top 5 by BM25:
#  1. TGTFDT8EZZNMZUZR  score=2.5668  Solid Women Black Cycling Shorts
#  2. TKPE7KJ9FZWSUFNF  score=2.2214  cycling Solid Men Black Track Pants
#  3. TGTFUDTM2TFPUYGM  score=1.8274  Solid Men Black Tights
#  4. SRTFVXWH44WVYC3E  score=1.5447  Dyed Men Black Regular Shorts
#  5. SRTEDGDPFYDQXNJF  score=1.3487  Solid Women Black Running Shorts
#
# Top 5 by Our Score:
#  1. TGTFDT8EZZNMZUZR  score=2.7941  Solid Women Black Cycling Shorts
#  2. TKPE7KJ9FZWSUFNF  score=2.0897  cycling Solid Men Black Track Pants
#  3. SRTFVXWH44WVYC3E  score=1.5725  Dyed Men Black Regular Shorts
#  4. TGTFUDTM2TFPUYGM  score=1.5611  Solid Men Black Tights
#  5. SRTEQKY62CMVFZNY  score=1.4304  Solid Men Black Beach Shorts, Gym Shorts, Night Shorts, Basic Shorts, Running Shorts, Boxer Shorts, Sports Shorts, Cycling Shorts
#
# Enter your query (or type 'exit' to quit): exit
# Exiting search test.

# %% [markdown]
# ### **2. Word2Vec with Cosine Ranking Score**

# %% [markdown]
# #### 2.1 Function Implementation

# %%
# Store each document as a unique list of words instead of having each feature separately
products = {}
for _, row in fashion_df_processed.iterrows():
    combined_text = row.get('title', '') \
                    + row.get('description', '') \
                    + row.get('category', '') \
                    + row.get('sub_category', '') \
                    + row.get('brand', '') \
                    + row.get('seller', '') \
                    + row.get('product_details', '')
    doc_id = row.get('pid')
    products[doc_id] = combined_text

# %%
# Train Word2Vec model with the processed documents
model = Word2Vec(list(products.values()), vector_size=100, window=5, min_count=1)

# %%
def doc2vec(model, words):
    """Convert document to vector considering the trained Word2Vec model"""
    words = [w for w in words if w in model.wv.key_to_index]
    if not words:
        return np.zeros(model.vector_size)
    return np.mean(model.wv[words], axis=0)

def word2vec_cosine_rank(query, documents, query_docs, model, build_terms_fn=build_terms, top_k=20):
    """Rank documents using Word2Vec with cosine similarity"""
    # Find vectors for the query and documents that containg all query words
    query = build_terms_fn(query)
    query_vector = doc2vec(model, query)
    doc_vectors = [doc2vec(model, doc) for doc_id, doc in documents.items() if doc_id in query_docs]

    # Compute cosine similarity
    similarity_scores = cosine_similarity([query_vector], doc_vectors).flatten()
    scores = {key: score for key, score in zip(query_docs, similarity_scores)}
    ranked_docs = sorted(zip(query_docs, similarity_scores), key=lambda x: x[1], reverse=True)

    return ranked_docs[:top_k], scores

# %%
while True:
    q = input("\nEnter your query (or type 'exit' to quit): ").strip()
    if q.lower() == "exit":
        print("Exiting search test.")
        break

    # Get docs with AND semantics
    docs = conjunctive_search_terms(q, index)
    if not docs:
        print("No documents found containing all query terms.")
        continue

    ranked_word2vec, _ = word2vec_cosine_rank(q, products, docs, model)
    print("\nTop 20 by Word2Vec with cosine similarity ranking:")
    for i, (doc_id, score) in enumerate(ranked_word2vec, 1):
        title = fashion_df.loc[fashion_df["pid"] == doc_id, "title"].values
        title = title[0] if len(title) else "(no title)"
        print(f"{i:2d}. {doc_id}  score={score:.4f}  {title}")

# Examples of queries to process:
    # query_1 = Comfort Women Dark Blue T-Shirt
    # query_2 = Green Stripe Men Cotton Polo
    # query_3 = Solid Track Black Pants for Men
    # query_4 = Print stylish pyjama
    # query_5 = Cycling Clothes in Black
# Out:
# Enter your query (or type 'exit' to quit): Comfort Women Dark Blue T-Shirt
#
# Top 20 by Word2Vec with cosine similarity ranking:
#  1. SWSFWEYZN5CY2DWE  score=0.7963  Full Sleeve Graphic Print Women Sweatshirt
#  2. TSHFHBNTJCCGDG6F  score=0.7954  Solid Women Polo Neck Dark Blue, Blue, Pink T-Shirt  (Pack of 3)
#  3. SWSFWEFYEW4AZYTZ  score=0.7928  Full Sleeve Graphic Print Women Sweatshirt
#  4. TSHE5BVTWMQZXXUM  score=0.7913  Solid Women Henley Dark Green, Blue T-Shirt  (Pack of 2)
#  5. TSHFTB6YXYGTFPQB  score=0.7876  Printed Women Round Neck Dark Blue T-Shirt
#  6. TSHE5GSJSVFNXHWZ  score=0.7833  Solid Women Henley Dark Blue, Dark Green, White T-Shirt  (Pack of 3)
#  7. TSHFTHSCVCCX76YH  score=0.7824  Printed Women Round Neck Dark Blue T-Shirt
#  8. SWSFWEFYTANC5XSS  score=0.7692  Full Sleeve Graphic Print Women Sweatshirt
#  9. TSHFG287GG6YHXZD  score=0.7668  Self Design Women Hooded Neck Dark Blue T-Shirt
# 10. TSHFDVE88Q6YJRXT  score=0.7660  Solid Women Round Neck Dark Blue T-Shirt
# 11. TSHFHHRHH8THU3VZ  score=0.7634  Solid Women Polo Neck Dark Blue, Pink, Orange T-Shirt  (Pack of 3)
# 12. TSHFGHWUFEFA8HCA  score=0.7620  Solid Women Polo Neck Dark Blue, Grey, Light Green T-Shirt  (Pack of 3)
# 13. TSHFK3W7SYEH9ZPY  score=0.7610  Solid Women Round Neck Dark Blue T-Shirt
# 14. TSHFNV9KJ4DPYDMG  score=0.7580  Superhero Women Round Neck Dark Blue T-Shirt
# 15. TKPFZMUZBHC9BZR2  score=0.7566  Solid Women Dark Blue Track Pants
# 16. TSHFMHQBHEAJNJD6  score=0.7558  Printed Women Round Neck Dark Blue T-Shirt
# 17. TSHFVR8FDGPHPZUA  score=0.7542  Solid Women Collared Neck Dark Blue T-Shirt
# 18. TSHFWYWEZCF9WHTF  score=0.7533  Printed Women Round Neck Dark Blue T-Shirt
# 19. TSHFR9ZPM97EYKH3  score=0.7531  Printed Women Collared Neck Dark Blue T-Shirt
# 20. TSHF34PEXH5AVGRR  score=0.7517  Solid Women Round Neck Grey T-Shirt
#
# Enter your query (or type 'exit' to quit): Green Stripe Men Cotton Polo
#
# Top 20 by Word2Vec with cosine similarity ranking:
#  1. TSHFUGP7GVGXJWTC  score=0.8550  Striped Men Polo Neck Green T-Shirt
#  2. TSHFPKNCFHB6QTFP  score=0.8487  Striped Men Polo Neck Green, Blue T-Shirt
#  3. TSHFVHCZNGFWK6Y7  score=0.8408  Printed Men Polo Neck Green T-Shirt
#  4. TSHFVQJQFDTTBYSH  score=0.8372  Striped Men Polo Neck Green T-Shirt
#  5. TSHFQEEQ2HA3EX96  score=0.8280  Striped Men Polo Neck Green T-Shirt
#  6. TSHFUXPWUR2ZTEE2  score=0.8241  Color Block Men V Neck Dark Blue T-Shirt
#  7. TSHFHG6GEBEN5B4F  score=0.8206  Striped Men Polo Neck Green T-Shirt
#  8. TSHFG2HTNYF2VG9Q  score=0.8022  Striped Men Polo Neck Multicolor T-Shirt  (Pack of 2)
#  9. TSHFVHCMCCMFWC4G  score=0.7993  Striped Men Polo Neck Green T-Shirt
# 10. TSHFG2HT8YNZHWA5  score=0.7945  Striped Men Polo Neck Multicolor T-Shirt  (Pack of 2)
# 11. TSHFG2HTXEHZNGGZ  score=0.7935  Striped Men Polo Neck Multicolor T-Shirt  (Pack of 2)
# 12. TSHFWDBQGSAQKTYG  score=0.7889  Solid Men Polo Neck Light Green T-Shirt
# 13. TSHFNEQ7Y9QAQRG5  score=0.7866  Striped Men Polo Neck Green T-Shirt
# 14. TSHFVSZ29JFQ7NH8  score=0.7862  Striped Men Polo Neck Light Green, Dark Blue T-Shirt
# 15. TSHFG2HTQDXM3SQX  score=0.7844  Striped Men Polo Neck Multicolor T-Shirt  (Pack of 2)
# 16. TSHFVQJRQQMSTHYS  score=0.7826  Striped Men Polo Neck Light Green T-Shirt
# 17. TSHFKKCXY9YYQP4U  score=0.7763  Striped Men Polo Neck Grey T-Shirt
# 18. TSHFG2HTGWSVXBZB  score=0.7755  Striped Men Polo Neck Multicolor T-Shirt  (Pack of 2)
# 19. TSHEUUPDTD5AKZP2  score=0.7724  Striped Men Polo Neck Green T-Shirt
# 20. TSHEUJ44HVSVX6JF  score=0.7718  Striped Men Polo Neck Green T-Shirt
#
# Enter your query (or type 'exit' to quit): Solid Track Black Pants for Men
#
# Top 20 by Word2Vec with cosine similarity ranking:
#  1. TKPFMTHZVDKGMFZX  score=0.8516  Solid Men Black Track Pants
#  2. TKPFJWYJTSDJGYU9  score=0.8453  Solid Men Black, Grey Track Pants
#  3. TKPE7KJ9FZWSUFNF  score=0.8393  cycling Solid Men Black Track Pants
#  4. TSHFSPXRZAHZWDZ8  score=0.8345  Solid Men Round Neck Dark Blue T-Shirt
#  5. TKPFVEV38QCHVWTN  score=0.8345  Solid Men Black Track Pants
#  6. TKSFJKWEKGMXPA6E  score=0.8345  Solid Men Track Suit
#  7. TKPFNV3FY7PYPHCZ  score=0.8278  Solid Men Grey Track Pants
#  8. TKPFUS4WEGXHTKJK  score=0.8278  Solid Men Black Track Pants
#  9. TSHFSPXRXCUHTSNB  score=0.8278  Solid Men Round Neck Black T-Shirt
# 10. TKPFHZH7CYDMURHX  score=0.8262  Solid Men Black Track Pants
# 11. TKSFVEV4HHUKUGUG  score=0.8250  Solid Men Track Suit
# 12. TKPFM2W2KNHFUBH2  score=0.8248  Solid Men Black Track Pants
# 13. TKPEYQ6YNHW8FV5R  score=0.8248  Solid Men Black, Orange Track Pants
# 14. TKPFYZ6FXKZ2JGKJ  score=0.8229  Solid Men Black Track Pants
# 15. TKPFE7E8GZVEGMC6  score=0.8215  Solid Men Black Track Pants
# 16. TKPFUVM3BKZCQYY8  score=0.8161  Solid Men Black Track Pants
# 17. TKPEQHGYQRXHCBFY  score=0.8080  Solid Men Black Track Pants
# 18. TKPFZ3JRST9YCECV  score=0.8064  Solid Men Black Track Pants
# 19. TKPFZ3JR5AHMQSXT  score=0.8056  Solid Men Black Track Pants
# 20. TKPFZKCZYCEFRVYY  score=0.8054  Solid Men Black Track Pants
#
# Enter your query (or type 'exit' to quit): Print stylish pyjama
#
# Top 20 by Word2Vec with cosine similarity ranking:
#  1. KTAFDVG4YZBS44WT  score=0.4698  Women Printed Cotton Blend Straight Kurta  (Blue, Orange)
#  2. KTAFDVG4TSDXEMCZ  score=0.4698  Men Printed Cotton Blend Straight Kurta  (Blue, Orange)
#  3. KTAFD3ZMEMREHQHS  score=0.4698  Women Printed Cotton Blend Straight Kurta  (Orange)
#  4. KTAFDVG4TF7ZFCQC  score=0.4698  Men Printed Cotton Blend Straight Kurta  (Blue, Orange)
#  5. PYJFX5SUNQGAFZ96  score=0.4664  Women Pyjama  (Pack of 1)
#  6. KTAFDVG4MFGKVFTE  score=0.4654  Men Printed Cotton Blend Straight Kurta  (Blue, Orange)
#  7. KTAFD3ZMWMWFHWHH  score=0.4652  Women Printed Cotton Blend Straight Kurta  (Orange)
#  8. KTAFD3ZMPXPC3GE4  score=0.4626  Women Printed Cotton Blend Straight Kurta  (Orange)
#  9. KTAFBCFZCBYFGW8H  score=0.4626  Women Printed Cotton Blend Straight Kurta  (Multicolor)
# 10. PYJFX5SSBZGHM2FU  score=0.4618  Men Pyjama  (Pack of 1)
# 11. PYJFX5SHQRGNYD7G  score=0.4618  Women Pyjama  (Pack of 1)
# 12. PYJFX5SPGAF8E49C  score=0.4616  Women Pyjama  (Pack of 1)
# 13. PYJFX5SMJQ9WNUQA  score=0.4616  Women Pyjama  (Pack of 1)
# 14. PYJFX5SVGHKJ9UQN  score=0.4616  Men Pyjama  (Pack of 1)
# 15. KTAFD3ZMZSMMHB5C  score=0.4607  Women Printed Cotton Blend Straight Kurta  (Orange)
# 16. PYJFX5SPDTCKQGUF  score=0.4594  Women Pyjama  (Pack of 1)
#
# Enter your query (or type 'exit' to quit): Cycling Clothes in Black
#
# Top 20 by Word2Vec with cosine similarity ranking:
#  1. TSHFVG9UHURRYKQY  score=0.6993  Solid Women Round Neck Multicolor T-Shirt  (Pack of 2)
#  2. TSHFVG9UQGFFVSZP  score=0.6993  Solid Men Round Neck Multicolor T-Shirt  (Pack of 2)
#  3. TSHFVG9UFYYGEPVV  score=0.6993  Solid Women Round Neck Multicolor T-Shirt  (Pack of 2)
#  4. SRTFVXWH44WVYC3E  score=0.6992  Dyed Men Black Regular Shorts
#  5. SOCF9GGDHSRJUGAD  score=0.6823  Men Solid Mid-Calf/Crew  (Pack of 3)
#  6. TSHFVG9UFAYWFTCG  score=0.6584  Solid Men Round Neck Multicolor T-Shirt  (Pack of 2)
#  7. TSHFVG9UFJCHEHPH  score=0.5665  Solid Men Round Neck Multicolor T-Shirt  (Pack of 2)
#  8. TSHFVG9UC6WZEZ5F  score=0.5071  Solid Men Round Neck Multicolor T-Shirt  (Pack of 2)
#  9. TSHFVG9UEGPZVHHG  score=0.4939  Solid Men Round Neck Multicolor T-Shirt  (Pack of 2)
# 10. TSHFVG9UMCMVQSJB  score=0.4911  Solid Men Round Neck Multicolor T-Shirt  (Pack of 2)
# 11. TSHFVG9UBHNM4QFC  score=0.4825  Solid Men Round Neck Multicolor T-Shirt  (Pack of 2)
# 12. TSHEGVS2YXWHCKEG  score=0.4751  Printed Men Round Neck Black T-Shirt
# 13. TSHE282KCQWXJUBD  score=0.4716  Solid Women Polo Neck Black T-Shirt
# 14. TSHFVG9U9G7AHC3P  score=0.4409  Solid Women Round Neck Multicolor T-Shirt  (Pack of 2)
# 15. TSHE22FQRVTGUWRZ  score=0.4407  Solid Women Polo Neck Blue T-Shirt
# 16. TSHFVG9UQ2TNQANJ  score=0.4356  Solid Women Round Neck Multicolor T-Shirt  (Pack of 2)
# 17. SRTFW4GC5YHGZY3A  score=0.4342  Solid Men Black Swim Shorts
# 18. TSHFVG9URXUK3UKR  score=0.4337  Solid Men Round Neck Multicolor T-Shirt  (Pack of 2)
# 19. TSHFVG9U7Q9RMSZQ  score=0.4333  Solid Men Round Neck Multicolor T-Shirt  (Pack of 2)
# 20. TSHFVG9UHTCB7YUZ  score=0.4333  Solid Women Round Neck Multicolor T-Shirt  (Pack of 2)
#
# Enter your query (or type 'exit' to quit): exit
# Exiting search test.
